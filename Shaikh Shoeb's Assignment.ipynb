# %% [markdown]
# # Constems-AI Systems Private Limited Assignment

# %% [markdown]
# Hello, I am shaikh shoeb, This is my assignment

# %% [markdown]
# ![randomnumber2.png](attachment:randomnumber2.png)

# %% [markdown]
# ### I am glad to have an opportunity to complete this assignment
#
# #### Assignment contains three questions
# #### These are
# ##### 1)  Write a well-documented function to generate random numbers from scratch without using any libraries in python?
# ##### 2)  Demonstrate that the function created generates random numbers using any statistical or visualization methods?
# ##### 3) predict the value of pi using the generated number?

# %% [markdown]
# ###### To solve the first question we will use Basic Math formula
#
# ## (a*x+c) mod m
# ##### in this we will seed 'a' to calculate next random number
# ##### 'a' will be the result of the previous calculation ('a' will be the previous random number)
# ##### 'm' will be any 3 or 4 digit number, because if we take 1 digit number we will end up having same number after one iteration

# %% [markdown]
# ##### 1) Write a well-documented function to generate random numbers from scratch without using any libraries in python?

# %%
# basic math function for random number (a*x+c)mod m, i should change every time to generate random number.
def random():                 # This is the function name random.
    list_1 = list()           # We create the list by appending ans into it.      
    ans =0                    # we will save the answer of the formula.
    for x in range(30):       # we are setting the range (it can be any range)
        for i in list_1:            
            ans = (i*5+7)%5345  #This is the basic math formula for calculating random numbers.
        list_1.append(ans)
        print(ans)
random()
# Out:
# 0
# 7
# 42
# 217
# 1092
# 122
# 617
# 3092
# 4777
# 2512
# 1877
# 4047
# 4207
# 5007
# 3662
# 2282
# 727
# 3642
# 2182
# 227
# 1142
# 372
# 1867
# 3997
# 3957
# 3757
# 2757
# 3102
# 4827
# 2762

# %% [markdown]
# ##### 2) Demonstrate that the function created generates random numbers using any statistical or visualization methods?

# %%
import matplotlib.pyplot as plt # Using Matplotlib library to plot generated random numbers.
def random():
    list_1 = list()                                           
    total = 0
    ans =0
    for x in range(30):
        for i in list_1:            
            ans = (i*5+7)%5345 
        list_1.append(ans)
    plt.plot(list_1)
random()

# %% [markdown]
# ##### 3) predict the value of pi using the generated number?
#
# ##### If we want to calculate pi value we need to generate two pairs of random number X and Y

# %% [markdown]
# ![pi%20value.jpg](attachment:pi%20value.jpg)

# %%
# fuction to calculate pi value of random numbers
def random():
    list_1 = list() 
    list_2 = list()
    X =0
    Y =0
    distence=0
    pointincircle=0
    pi=0
    for x in range(30):
        for i in list_1:            
            X = (i*5+7)%5345 
            Y = (i*5+4)%9443
        list_1.append(X)
        list_2.append(Y)
        distence = (X*X + Y*Y)**0.5    
        if distence < 1:
            pointincircle += 1
        pi = 4 * pointincircle/30           
    print(" pi value",pi)
random()
# Out:
#  pi value 0.13333333333333333

# %% [markdown]
# ## Thank you

# %% [markdown]
# ##### Name : Shaikh Shoeb
# ##### email : shoeb9530@gmail.com
# ##### phone no: +91 7558553638
